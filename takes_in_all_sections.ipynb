# %%
import pandas as pd

df = pd.read_csv('Processed_Headings/combined.csv')
df.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0       PMCID      PMID  \
# 0             0             0             0           0  PMC7000045  31567706
# 1             1             1             1           1  PMC7000045  31567706
# 2             2             2             2           2  PMC7000045  31567706
# 3             3             3             3           3  PMC7000045  31567706
# 4             4             4             4           4  PMC7000113  31888964
#
#                                           xmlPath          sec-type  \
# 0             article > body > sec > Introduction             intro
# 1     article > body > sec > Patients and Methods  patients|methods
# 2                  article > body > sec > Results           results
# 3               article > body > sec > Discussion        discussion
# 4  article > body > sec > EXPERIMENTAL PROCEDURES           methods
#
#                  sec-title average_prediction supervised_prediction  \
# ...

# %%
df2 = pd.read_csv('Processed_Headings/normalized_section_data 2.csv')
df2.head()
# Out:
#         PMCID      PMID sec-type                          sec-title  \
# 0  PMC5427117  28337662      NaN                       Introduction
# 1  PMC5427117  28337662      NaN                            Methods
# 2  PMC5427117  28337662      NaN                            Results
# 3  PMC5427117  28337662      NaN                         Discussion
# 4  PMC5427117  28337662      NaN  Electronic supplementary material
#
#       sec-norm
# 0   background
# 1      methods
# 2      results
# 3  conclusions
# 4   background

# %%
df = df.drop(columns=["Unnamed: 0.2", "Unnamed: 0.1", "Unnamed: 0", "sec-norm", "Unnamed: 0.3"])

# %%
df.head()
# Out:
#         PMCID      PMID                                         xmlPath  \
# 0  PMC7000045  31567706             article > body > sec > Introduction
# 1  PMC7000045  31567706     article > body > sec > Patients and Methods
# 2  PMC7000045  31567706                  article > body > sec > Results
# 3  PMC7000045  31567706               article > body > sec > Discussion
# 4  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
#
#            sec-type                sec-title average_prediction  \
# 0             intro             Introduction         background
# 1  patients|methods     Patients and Methods            methods
# 2           results                  Results            results
# 3        discussion               Discussion        conclusions
# 4           methods  EXPERIMENTAL PROCEDURES            methods
#
#   supervised_prediction
# 0            background
# 1               methods
# 2               results
# 3           conclusions
# ...

# %%
merged_df = df.merge(df2, on=["PMCID", "PMID", "sec-type", "sec-title"], how="left")
merged_df.head()
# Out:
#         PMCID      PMID                                         xmlPath  \
# 0  PMC7000045  31567706             article > body > sec > Introduction
# 1  PMC7000045  31567706     article > body > sec > Patients and Methods
# 2  PMC7000045  31567706                  article > body > sec > Results
# 3  PMC7000045  31567706               article > body > sec > Discussion
# 4  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
#
#            sec-type                sec-title average_prediction  \
# 0             intro             Introduction         background
# 1  patients|methods     Patients and Methods            methods
# 2           results                  Results            results
# 3        discussion               Discussion        conclusions
# 4           methods  EXPERIMENTAL PROCEDURES            methods
#
#   supervised_prediction     sec-norm
# 0            background   background
# 1               methods      methods
# ...

# %%
merged_df.head(10)
# Out:
#         PMCID      PMID                                         xmlPath  \
# 0  PMC7000045  31567706             article > body > sec > Introduction
# 1  PMC7000045  31567706     article > body > sec > Patients and Methods
# 2  PMC7000045  31567706                  article > body > sec > Results
# 3  PMC7000045  31567706               article > body > sec > Discussion
# 4  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
# 5  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
# 6  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
# 7  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
# 8  PMC7000113  31888964  article > body > sec > EXPERIMENTAL PROCEDURES
# 9  PMC7000113  31888964                  article > body > sec > RESULTS
#
#            sec-type                sec-title average_prediction  \
# 0             intro             Introduction         background
# ...

# %%
len(df), len(df2)
# Out:
# (37642687, 37642680)

# %%
merged_df.to_csv('Processed_Headings/merged.csv')

# %%
import pandas as pd
merged_df = pd.read_csv('Processed_Headings/merged.csv')

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
# Out:
# /var/tmp/ipykernel_99847/451148544.py:2: DtypeWarning: Columns (4,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df = pd.read_csv('Processed_Headings/merged.csv')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 merged_df = pd.read_csv('Processed_Headings/merged.csv')
#       4 from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
# ----> 6 df_filtered = df.dropna(subset=['sec-norm'])
#       8 y_true = df_filtered['sec-norm'].astype(int)
#       9 y_pred = df_filtered['prediction'].astype(int)
#
# NameError: name 'df' is not defined

# %%
df_filtered = merged_df.dropna(subset=['sec-norm'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 df_filtered = merged_df.dropna(subset=['sec-norm'])
# ----> 3 y_true = df_filtered['sec-norm'].astype(int)
#       4 y_pred = df_filtered['prediction'].astype(int)
#       6 precision = precision_score(y_true, y_pred, average='macro')
#
# File /opt/packages/anaconda3-2024.10-1/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
y_true = df_filtered['sec-norm']
y_pred = df_filtered['supervised_prediction']

precision = precision_score(y_true, y_pred, average='macro') 
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
accuracy = accuracy_score(y_true, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Macro Precision: {precision:.4f}")
print(f"Macro Recall: {recall:.4f}")
print(f"Macro F1-score: {f1:.4f}")

precision = precision_score(y_true, y_pred, average='micro')  
recall = recall_score(y_true, y_pred, average='micro')
f1 = f1_score(y_true, y_pred, average='micro')
accuracy = accuracy_score(y_true, y_pred)

print(f"Micro Precision: {precision:.4f}")
print(f"Micro Recall: {recall:.4f}")
print(f"Micro F1-score: {f1:.4f}")

precision = precision_score(y_true, y_pred, average='weighted')  
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
accuracy = accuracy_score(y_true, y_pred)

print(f"Weighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
print(f"Weighted F1-score: {f1:.4f}")
# Out:
# Accuracy: 1.0000
# Macro Precision: 1.0000
# Macro Recall: 1.0000
# Macro F1-score: 1.0000
# Micro Precision: 1.0000
# Micro Recall: 1.0000
# Micro F1-score: 1.0000
# Weighted Precision: 1.0000
# Weighted Recall: 1.0000
# Weighted F1-score: 1.0000

# %%
y_true = df_filtered['sec-norm']
y_pred = df_filtered['average_prediction']

precision = precision_score(y_true, y_pred, average='macro') 
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
accuracy = accuracy_score(y_true, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Macro Precision: {precision:.4f}")
print(f"Macro Recall: {recall:.4f}")
print(f"Macro F1-score: {f1:.4f}")

precision = precision_score(y_true, y_pred, average='micro')  
recall = recall_score(y_true, y_pred, average='micro')
f1 = f1_score(y_true, y_pred, average='micro')
accuracy = accuracy_score(y_true, y_pred)

print(f"Micro Precision: {precision:.4f}")
print(f"Micro Recall: {recall:.4f}")
print(f"Micro F1-score: {f1:.4f}")

precision = precision_score(y_true, y_pred, average='weighted')  
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')
accuracy = accuracy_score(y_true, y_pred)

print(f"Weighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
print(f"Weighted F1-score: {f1:.4f}")
# Out:
# Accuracy: 1.0000
# Macro Precision: 1.0000
# Macro Recall: 1.0000
# Macro F1-score: 1.0000
# Micro Precision: 1.0000
# Micro Recall: 1.0000
# Micro F1-score: 1.0000
# Weighted Precision: 1.0000
# Weighted Recall: 1.0000
# Weighted F1-score: 1.0000
